# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sensor_1_data = np.linspace(-3, 2, 1000)
sensor_2_data = np.linspace(3, -2, 1000)

direction = 

plot = plt.plot(sensor_1_data, label='Sensor 1')
plot = plt.plot(sensor_2_data, label='Sensor 2')
plt.legend()
